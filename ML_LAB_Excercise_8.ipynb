# %% [markdown]
# Using id3

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

id3_model = DecisionTreeClassifier(criterion='entropy', splitter='best', random_state=42)
id3_model.fit(X_train, y_train)
id3_pred = id3_model.predict(X_test)

print("ID3 Results")
print("Accuracy:", accuracy_score(y_test, id3_pred))
print(classification_report(y_test, id3_pred, target_names=iris.target_names))

plt.figure(figsize=(12,8))
plot_tree(id3_model, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.title("ID3 Decision Tree")
plt.show()
# Out:
# ID3 Results
# Accuracy: 0.8888888888888888
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.81      0.87      0.84        15
#    virginica       0.86      0.80      0.83        15
#
#     accuracy                           0.89        45
#    macro avg       0.89      0.89      0.89        45
# weighted avg       0.89      0.89      0.89        45

# %% [markdown]
# Using cart

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

cart_model = DecisionTreeClassifier(criterion='gini', splitter='best', random_state=42)
cart_model.fit(X_train, y_train)
cart_pred = cart_model.predict(X_test)

print("CART Results")
print("Accuracy:", accuracy_score(y_test, cart_pred))
print(classification_report(y_test, cart_pred, target_names=iris.target_names))

plt.figure(figsize=(12,8))
plot_tree(cart_model, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.title("CART Decision Tree")
plt.show()
# Out:
# CART Results
# Accuracy: 0.9333333333333333
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.80      0.89        15
#    virginica       0.83      1.00      0.91        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45

# %% [markdown]
# Using c4.5

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

c45_model = DecisionTreeClassifier(criterion='entropy', splitter='best', random_state=42)
c45_model.fit(X_train, y_train)
c45_pred = c45_model.predict(X_test)

print("C4.5 Results")
print("Accuracy:", accuracy_score(y_test, c45_pred))
print(classification_report(y_test, c45_pred, target_names=iris.target_names))

plt.figure(figsize=(12,8))
plot_tree(c45_model, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.title("C4.5 Decision Tree")
plt.show()
# Out:
# C4.5 Results
# Accuracy: 0.8888888888888888
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.81      0.87      0.84        15
#    virginica       0.86      0.80      0.83        15
#
#     accuracy                           0.89        45
#    macro avg       0.89      0.89      0.89        45
# weighted avg       0.89      0.89      0.89        45
